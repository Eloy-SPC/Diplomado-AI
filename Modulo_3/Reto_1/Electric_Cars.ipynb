# %%
import pandas as pd

# %%
#lectura de datos

df=pd.read_csv('Cheapestelectriccars-EVDatabase 2023.csv')
df
# Out:
#                                    Name  \
# 0             Lucid Air Dream Edition P
# 1                Porsche Taycan Turbo S
# 2                     Audi e-tron GT RS
# 3                 Renault Zoe ZE50 R110
# 4                     Audi Q4 e-tron 35
# ..                                  ...
# 304                 Volkswagen ID.7 Pro
# 305               Volkswagen ID.7 Pro S
# 306  Polestar 4 Long Range Single Motor
# 307    Polestar 4 Long Range Dual Motor
# 308            Maserati Grecale Folgore
#
#                                               Subtitle Acceleration  TopSpeed  \
# 0    118 kWh useable battery          Available sin...      2.7 sec       270
# 1    83.7 kWh useable battery          Available si...      2.8 sec       260
# 2    85 kWh useable battery          Available sinc...      3.3 sec       250
# 3    52 kWh useable battery          Available sinc...     11.4 sec       135
# 4    52 kWh useable battery          Available sinc...      9.0 sec       160
# ...

# %%
df.head(2) #Primeras 2 filas
# Out:
#                         Name  \
# 0  Lucid Air Dream Edition P
# 1     Porsche Taycan Turbo S
#
#                                             Subtitle Acceleration  TopSpeed  \
# 0  118 kWh useable battery          Available sin...      2.7 sec       270
# 1  83.7 kWh useable battery          Available si...      2.8 sec       260
#
#    Range  Efficiency FastChargeSpeed            Drive  NumberofSeats  \
# 0    645         183             820  All Wheel Drive              5
# 1    400         209             980  All Wheel Drive              4
#
#   PriceinGermany PriceinUK
# 0        218,000       NaN
# 1        189,668   142,400

# %%
df.tail(2) #ultimas 2 filas
# Out:
#                                  Name  \
# 307  Polestar 4 Long Range Dual Motor
# 308          Maserati Grecale Folgore
#
#                                               Subtitle Acceleration  TopSpeed  \
# 307  94 kWh useable battery          Expected from ...      3.8 sec       200
# 308  95 kWh useable battery          Expected from ...      4.1 sec       220
#
#      Range  Efficiency FastChargeSpeed            Drive  NumberofSeats  \
# 307    475         198             710  All Wheel Drive              5
# 308    405         235             440  All Wheel Drive              5
#
#     PriceinGermany PriceinUK
# 307         65,000    60,000
# 308            NaN   135,000

# %%
df.head(3)
# Out:
#                         Name  \
# 0  Lucid Air Dream Edition P
# 1     Porsche Taycan Turbo S
# 2          Audi e-tron GT RS
#
#                                             Subtitle Acceleration  TopSpeed  \
# 0  118 kWh useable battery          Available sin...      2.7 sec       270
# 1  83.7 kWh useable battery          Available si...      2.8 sec       260
# 2  85 kWh useable battery          Available sinc...      3.3 sec       250
#
#    Range  Efficiency FastChargeSpeed            Drive  NumberofSeats  \
# 0    645         183             820  All Wheel Drive              5
# 1    400         209             980  All Wheel Drive              4
# 2    405         210            1000  All Wheel Drive              4
#
#   PriceinGermany PriceinUK
# 0        218,000       NaN
# 1        189,668   142,400
# 2        146,050   115,000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 309 entries, 0 to 308
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             309 non-null    object
#  1   Subtitle         309 non-null    object
#  2   Acceleration     309 non-null    object
#  3   TopSpeed         309 non-null    int64
#  4   Range            309 non-null    int64
#  5   Efficiency       309 non-null    int64
#  6   FastChargeSpeed  309 non-null    object
#  7   Drive            309 non-null    object
#  8   NumberofSeats    309 non-null    int64
#  9   PriceinGermany   282 non-null    object
#  10  PriceinUK        198 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 26.7+ KB

# %%
df['Efficiency'].unique()#Inspeccionar cada variable
#Con el unique borras los valores repetidos
# Out:
# array([183, 209, 210, 165, 182, 181, 197, 168, 202, 167, 176, 180, 295,
#        191, 172, 164, 162, 178, 193, 159, 200, 207, 188, 160, 157, 158,
#        216, 250, 257, 262, 173, 161, 217, 208, 171, 177, 185, 189, 199,
#        192, 190, 166, 186, 226, 232, 194, 187, 293, 151, 179, 155, 290,
#        286, 163, 195, 212, 174, 203, 233, 219, 224, 206, 175, 152, 169,
#        196, 150, 156, 211, 251, 254, 170, 214, 218, 228, 213, 220, 238,
#        235, 243, 240, 198, 205, 230, 237, 223, 222, 261, 184])

# %%
df.nunique()#Numero de elementos unicos que hay por columna
# Out:
# Name               308
# Subtitle           187
# Acceleration        84
# TopSpeed            36
# Range               80
# Efficiency          89
# FastChargeSpeed     91
# Drive                3
# NumberofSeats        4
# PriceinGermany     250
# PriceinUK          185
# dtype: int64

# %%
#df.columns.to_list() #Genera una lista de los nombres de las columnas en las tablas

for name in df.columns.to_list():
    print(f'La columna: {name} contiene los elementos {df[name].unique()}')
# Out:
# La columna: Name contiene los elementos ['Lucid Air Dream Edition P' 'Porsche Taycan Turbo S' 'Audi e-tron GT RS'
#  'Renault Zoe ZE50 R110' 'Audi Q4 e-tron 35' 'Tesla Model Y Performance'
#  'Porsche Taycan 4 Cross Turismo' 'Renault Zoe ZE50 R135'
#  'Porsche Taycan Turbo' 'Smart EQ fortwo coupe' 'Smart EQ fortwo cabrio'
#  'Honda e Advance' 'Porsche Taycan 4S' 'Porsche Taycan 4S Plus'
#  'Mercedes EQV 300 Long' 'Lexus UX 300e' 'BMW i4 eDrive40'
#  'Renault Twingo Electric' 'Fiat 500e Cabrio 42 kWh' 'Skoda Enyaq iV 60'
#  'Skoda Enyaq iV 80' 'Skoda Enyaq iV 80x' 'Skoda Enyaq iV RS'
#  'Fiat 500e Hatchback 42 kWh' 'Audi Q4 Sportback e-tron 35'
#  'Nissan Ariya 63kWh' 'Nissan Ariya 87kWh'
#  'Nissan Ariya e-4ORCE 87kWh - 225 kW'
#  'Nissan Ariya e-4ORCE 87kWh - 290 kW' 'Volkswagen ID.4 Pro Performance'
#  'Mercedes EQV 300 Extra-Long' 'Lucid Air Grand Touring'
#  'Lucid Air Touring' 'Lucid Air Pure' 'Fiat 500e Hatchback 24 kWh'
#  'Fiat 500e 3+1 42 kWh' 'Mercedes EQC 400 4MATIC'
# ...

# %%
df_clean=df
df_clean
# Out:
#                                    Name  \
# 0             Lucid Air Dream Edition P
# 1                Porsche Taycan Turbo S
# 2                     Audi e-tron GT RS
# 3                 Renault Zoe ZE50 R110
# 4                     Audi Q4 e-tron 35
# ..                                  ...
# 304                 Volkswagen ID.7 Pro
# 305               Volkswagen ID.7 Pro S
# 306  Polestar 4 Long Range Single Motor
# 307    Polestar 4 Long Range Dual Motor
# 308            Maserati Grecale Folgore
#
#                                               Subtitle Acceleration  TopSpeed  \
# 0    118 kWh useable battery          Available sin...      2.7 sec       270
# 1    83.7 kWh useable battery          Available si...      2.8 sec       260
# 2    85 kWh useable battery          Available sinc...      3.3 sec       250
# 3    52 kWh useable battery          Available sinc...     11.4 sec       135
# 4    52 kWh useable battery          Available sinc...      9.0 sec       160
# ...

# %%
df_clean.describe()
# Out:
#          TopSpeed       Range  Efficiency  NumberofSeats
# count  309.000000  309.000000  309.000000     309.000000
# mean   180.754045  361.440129  199.430421       5.284790
# std     38.738187  110.861212   33.021626       0.978567
# min    125.000000   95.000000  150.000000       2.000000
# 25%    150.000000  275.000000  174.000000       5.000000
# 50%    180.000000  370.000000  192.000000       5.000000
# 75%    200.000000  440.000000  214.000000       5.000000
# max    320.000000  685.000000  295.000000       7.000000

# %%
Traccion_Full=df_clean[df_clean['Drive']=='All Wheel Drive']
Traccion_Front=df_clean[df_clean['Drive']=='Front Wheel Drive']
Traccion_Rear=df_clean[df_clean['Drive']=='Rear Wheel Drive']

# %%
Traccion_Rear['Drive'].unique()
# Out:
# array(['Rear Wheel Drive'], dtype=object)

# %%
Traccion_Full.describe()
# Out:
#          TopSpeed       Range  Efficiency  NumberofSeats
# count  128.000000  128.000000  128.000000     128.000000
# mean   212.148438  437.421875  199.648438       5.062500
# std     32.058777   71.425266   18.918636       0.739759
# min    160.000000  305.000000  155.000000       4.000000
# 25%    185.000000  398.750000  187.750000       5.000000
# 50%    200.000000  425.000000  199.000000       5.000000
# 75%    241.250000  476.250000  209.000000       5.000000
# max    320.000000  685.000000  254.000000       7.000000

# %%
Precio=df_clean[(df_clean['Efficiency']> 200)& (df_clean['TopSpeed']>250)]

# %%
Precio
# Out:
#                                      Name  \
# 1                  Porsche Taycan Turbo S
# 8                    Porsche Taycan Turbo
# 54                    Tesla Model X Plaid
# 151    Porsche Taycan Turbo Sport Turismo
# 152  Porsche Taycan Turbo S Sport Turismo
# 236                        Lotus Eletre R
#
#                                               Subtitle Acceleration  TopSpeed  \
# 1    83.7 kWh useable battery          Available si...      2.8 sec       260
# 8    83.7 kWh useable battery          Available si...      3.2 sec       260
# 54   95 kWh useable battery          Available sinc...      2.6 sec       262
# 151  83.7 kWh useable battery          Available si...      3.2 sec       260
# 152  83.7 kWh useable battery          Available si...      2.8 sec       260
# 236  107 kWh useable battery          Available sin...      2.9 sec       260
#
#      Range  Efficiency FastChargeSpeed            Drive  NumberofSeats  \
# ...

# %%
Precio=df_clean[(df_clean['Drive']=='Rear Wheel Drive')& (df_clean['TopSpeed']>200)]

# %%
Precio
# Out:
#                                        Name  \
# 49                          Porsche Taycan
# 50                      Porsche Taycan Plus
# 73                        Mercedes EQS 450+
# 97                        Mercedes EQE 350+
# 106                          Tesla Model 3
# 147            Porsche Taycan Sport Turismo
# 148       Porsche Taycan Plus Sport Turismo
# 173                   Mercedes EQS SUV 450+
# 196                        Mercedes EQE 300
# 197                        Mercedes EQE 350
# 211                          Tesla Model Y
# 228                   Mercedes EQE SUV 350+
# 283  Polestar 2 Standard Range Single Motor
# 284      Polestar 2 Long Range Single Motor
#
#                                               Subtitle Acceleration  TopSpeed  \
# 49   71 kWh useable battery          Available sinc...      5.4 sec       230
# 50   83.7 kWh useable battery          Available si...      5.4 sec       230
# ...
