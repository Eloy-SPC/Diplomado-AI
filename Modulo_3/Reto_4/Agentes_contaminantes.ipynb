# %% [markdown]
# # AGENTES CONTAMINANTES

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %reset -f # Elimina todas las variables del entorno
# Out:
# Don't know how to reset  #, please run `%reset?` for details
# Don't know how to reset  elimina, please run `%reset?` for details
# Don't know how to reset  todas, please run `%reset?` for details
# Don't know how to reset  las, please run `%reset?` for details
# Don't know how to reset  variables, please run `%reset?` for details
# Don't know how to reset  del, please run `%reset?` for details
# Don't know how to reset  entorno, please run `%reset?` for details

# %% [markdown]
# ## Lectura de datos

# %%
df_contaminacion=pd.read_csv('rama_2023_05_missing_outliers_limited.csv')
df_contaminacion
# Out:
#            fecha        CO         NO        NO2        NOX         O3  \
# 0     2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1     2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2     2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3     2015-01-04  0.726940  24.606272  19.560976        NaN  17.329032
# 4     2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
# ...          ...       ...        ...        ...        ...        ...
# 3068  2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069  2023-05-28  0.286826        NaN  16.349241  20.230769  36.913761
# 3070  2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071  2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072  2023-05-31  0.340404   5.353066        NaN  25.710359        NaN
#
#             PM10       PM25        SO2
# 0     105.573684  78.953405  11.554723
# ...

# %%
df_contaminacion.head()
# Out:
#         fecha        CO         NO        NO2        NOX         O3  \
# 0  2015-01-01  1.050696  22.765528  24.225155  46.987578  23.175150
# 1  2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366
# 2  2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486
# 3  2015-01-04  0.726940  24.606272  19.560976        NaN  17.329032
# 4  2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588
#
#          PM10       PM25        SO2
# 0  105.573684  78.953405  11.554723
# 1   36.687845  15.449438        NaN
# 2   29.269022  12.915129   1.436937
# 3   39.961538  16.838284   1.809061
# 4   31.855643        NaN   8.315789

# %%
df_contaminacion.tail()
# Out:
#            fecha        CO         NO        NO2        NOX         O3  \
# 3068  2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645
# 3069  2023-05-28  0.286826        NaN  16.349241  20.230769  36.913761
# 3070  2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068
# 3071  2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971
# 3072  2023-05-31  0.340404   5.353066        NaN  25.710359        NaN
#
#            PM10       PM25       SO2
# 3068        NaN  21.170139  2.735683
# 3069  28.580000  18.454861  2.331658
# 3070  30.241486  16.692857  1.071588
# 3071  35.859532  20.888525  1.181818
# 3072  42.203390  24.787097  1.402083

# %%
df_contaminacion.describe()
# Out:
#                 CO           NO          NO2          NOX           O3  \
# count  2916.000000  2918.000000  2916.000000  2931.000000  2916.000000
# mean      0.546324    16.865058    22.964047    38.081554    30.462022
# std       1.547938    52.445837     6.738178    14.808493     8.996061
# min       0.115917     1.168000     8.061630     9.983402     3.226054
# 25%       0.328456     8.071004    18.149000    27.008633    23.912015
# 50%       0.446299    12.719253    22.364633    35.902381    29.850776
# 75%       0.601357    19.396523    26.779887    46.770094    36.147095
# max      43.237677  1423.223082    72.193452   148.005952    67.443750
#
#               PM10         PM25          SO2
# count  2931.000000  2928.000000  2936.000000
# mean     47.145281    23.809324     4.255579
# std     128.824262    62.176052    13.793875
# min       8.218487     2.849315     0.630435
# 25%      29.542437    15.307906     1.562846
# 50%      40.131720    20.526173     2.514104
# ...

# %%
df_contaminacion['fecha']
# Out:
# 0       2015-01-01
# 1       2015-01-02
# 2       2015-01-03
# 3       2015-01-04
# 4       2015-01-05
#            ...
# 3068    2023-05-27
# 3069    2023-05-28
# 3070    2023-05-29
# 3071    2023-05-30
# 3072    2023-05-31
# Name: fecha, Length: 3073, dtype: object

# %%
df_contaminacion['fecha'] = pd.to_datetime(df_contaminacion['fecha'], format= '%Y-%m-%d')

# %%
df_contaminacion.set_index('fecha', inplace=True)

# %% [markdown]
# ## 2 Grafico de variables

# %%
def plot_time_series(df, variables, ylabel, title, start_date=None, end_date=None):
    plt.figure(figsize=(15, 5))
    
    if start_date and end_date:
        df = df.loc[start_date:end_date]
    
    for variable in variables:
        if variable in df.columns:
            plt.plot(df.index, df[variable], label=variable)
        else:
            print(f"Columna '{variable}' no encontrada en el DataFrame")
    
    plt.xlabel('Fecha')
    plt.ylabel(ylabel)
    plt.title(title)
    plt.legend()
    plt.show()

# %%
plot_time_series(df_contaminacion,['CO'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['NO'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['NO2'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['O3'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['PM10'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['PM25'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')
plot_time_series(df_contaminacion,['SO2'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')

# %% [markdown]
# ## 3 Identificación y manejo de valores atípicos

# %% [markdown]
# ### outlayer por nan

# %%
Q1= df_contaminacion['CO'].quantile(0.25)
Q3= df_contaminacion['CO'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['CO'] = df_contaminacion['CO'].astype(float)

outliers = (df_contaminacion['CO'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['CO'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'CO'] = np.nan
# Out:
# -0.07280239964545981
# 0.9873323213653343

# %%
Q1= df_contaminacion['NO'].quantile(0.25)
Q3= df_contaminacion['NO'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['NO'] = df_contaminacion['NO'].astype(float)

outliers = (df_contaminacion['NO'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['NO'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'NO'] = np.nan
# Out:
# -8.917274816874642
# 36.38480134096411

# %%
Q1= df_contaminacion['NO2'].quantile(0.25)
Q3= df_contaminacion['NO2'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['NO2'] = df_contaminacion['NO2'].astype(float)

outliers = (df_contaminacion['NO2'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['NO2'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'NO2'] = np.nan
# Out:
# 5.202670371312973
# 39.726217144190244

# %%
Q1= df_contaminacion['NOX'].quantile(0.25)
Q3= df_contaminacion['NOX'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['NOX'] = df_contaminacion['NOX'].astype(float)

outliers = (df_contaminacion['NOX'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['NOX'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'NOX'] = np.nan
# Out:
# -2.633559483117434
# 76.41228600160113

# %%
Q1= df_contaminacion['O3'].quantile(0.25)
Q3= df_contaminacion['O3'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['O3'] = df_contaminacion['O3'].astype(float)

outliers = (df_contaminacion['O3'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['O3'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'O3'] = np.nan
# Out:
# 5.559395728944619
# 54.49971493481195

# %%
Q1= df_contaminacion['PM10'].quantile(0.25)
Q3= df_contaminacion['PM10'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['PM10'] = df_contaminacion['PM10'].astype(float)

outliers = (df_contaminacion['PM10'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['PM10'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'PM10'] = np.nan
# Out:
# -5.509170550050008
# 87.96178242687199

# %%
Q1= df_contaminacion['PM25'].quantile(0.25)
Q3= df_contaminacion['PM25'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['PM25'] = df_contaminacion['PM25'].astype(float)

outliers = (df_contaminacion['PM25'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['PM25'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'PM25'] = np.nan
# Out:
# -1.041345510192011
# 42.55665915796706

# %%
Q1= df_contaminacion['SO2'].quantile(0.25)
Q3= df_contaminacion['SO2'].quantile(0.75)

IQR = Q3-Q1

limite_inferior = Q1 - 1.5 * IQR
print(limite_inferior)
limite_superior= Q3 +1.5* IQR
print(limite_superior)

df_contaminacion['SO2'] = df_contaminacion['SO2'].astype(float)

outliers = (df_contaminacion['SO2'] < (Q1 - 1.5 * IQR)) | (df_contaminacion['SO2'] > (Q3 + 1.5 * IQR))
df_contaminacion.loc[outliers, 'SO2'] = np.nan
# Out:
# -2.6786859460238768
# 8.632066083884574

# %% [markdown]
# ### Eliminar valores nulos

# %%
df_contaminacion
# Out:
#                   CO         NO        NO2        NOX         O3       PM10  \
# fecha
# 2015-01-01       NaN  22.765528  24.225155  46.987578  23.175150        NaN
# 2015-01-02  0.807585  32.249608  21.554160  53.800628  17.268366  36.687845
# 2015-01-03  0.640755  21.686916  19.394081  41.071651  15.486486  29.269022
# 2015-01-04  0.726940  24.606272  19.560976        NaN  17.329032  39.961538
# 2015-01-05  0.530815  11.443182  20.990260  32.439935  14.470588  31.855643
# ...              ...        ...        ...        ...        ...        ...
# 2023-05-27  0.256722   3.750583  17.284351  21.629371  41.580645        NaN
# 2023-05-28  0.286826        NaN  16.349241  20.230769  36.913761  28.580000
# 2023-05-29  0.482077  11.448113  24.521154  36.436321  29.697068  30.241486
# 2023-05-30  0.441455  13.893519  22.615530  37.224537  36.185971  35.859532
# 2023-05-31  0.340404   5.353066        NaN  25.710359        NaN  42.203390
#
#                  PM25       SO2
# fecha
# ...

# %%
valores_nulos=df_contaminacion.isnull().sum()
valores_nulos
# Out:
# CO      227
# NO      233
# NO2     214
# NOX     190
# O3      176
# PM10    166
# PM25    200
# SO2     388
# dtype: int64

# %%
porcentaje= (valores_nulos / len(df_contaminacion))*100

porcentaje
# Out:
# CO       7.386918
# NO       7.582167
# NO2      6.963879
# NOX      6.182883
# O3       5.727302
# PM10     5.401887
# PM25     6.508298
# SO2     12.626098
# dtype: float64

# %%
df_contaminacion_sn_na = df_contaminacion.dropna(subset=['CO','NO','NO2','NOX','O3','PM10','PM25','SO2'])

# %%
valores_nulos2=df_contaminacion_sn_na.isnull().sum()
valores_nulos2
# Out:
# CO        0
# NO      148
# NO2     153
# NOX     131
# O3      146
# PM10    127
# PM25    139
# SO2     128
# dtype: int64

# %%
plot_time_series(df_contaminacion_sn_na,['CO'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['NO'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['NO2'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['O3'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['PM10'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['PM25'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')
plot_time_series(df_contaminacion_sn_na,['SO2'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2024-12-30')

# %%
plot_time_series(df_contaminacion_sn_na,['CO','NO','NO2','NOX','O3','PM10','PM25','SO2'],'COTAMINACION','Agentes contaminantes',start_date='2016-01-01', end_date='2018-12-30')

# %%
df_contaminacion_sn_na.describe()
# Out:
#                 CO           NO          NO2          NOX           O3  \
# count  1878.000000  1878.000000  1878.000000  1878.000000  1878.000000
# mean      0.450949    13.410098    21.950212    35.620224     0.450949
# std       0.169904     7.321846     5.737034    12.306549     0.169904
# min       0.115917     1.589286     8.061630    10.345588     0.115917
# 25%       0.317475     7.526062    17.714148    25.975165     0.317475
# 50%       0.427791    11.979032    21.529165    34.153697     0.427791
# 75%       0.557904    18.011583    25.873875    43.764384     0.557904
# max       0.973987    36.159420    39.633681    74.204082     0.973987
#
#               PM10         PM25          SO2
# count  1878.000000  1878.000000  1878.000000
# mean     39.227585    19.877486     2.814350
# std      14.181786     7.136118     1.746024
# min       8.218487     4.447368     0.630435
# 25%      28.365226    14.784868     1.486479
# 50%      37.850246    19.547233     2.262510
# ...
